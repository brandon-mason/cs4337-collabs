# %% [markdown]
# <a href="https://colab.research.google.com/github/brandon-mason/cs4337-collabs/blob/main/HandsOnPytorch_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install pytorch-lightning wandb
#  torch tensorboard
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 60.6 MB/s eta 0:00:00

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset, random_split
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger, WandbLogger
from pytorch_lightning.callbacks import ModelCheckpoint
import wandb
from sklearn.datasets import make_regression
import numpy as np

# Initialize Wandb
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: aiwand (txst) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: aiwand (txst) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# Step 1: Data Preparation
class RegressionDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)
X, y = X.astype(np.float32), y.astype(np.float32)
dataset = RegressionDataset(X, y)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# Step 2: Model Definition
class RegressionModel(nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
        self.layer1 = nn.Linear(10, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = self.layer3(x)
        return x

# Step 3: LightningModule
class RegressionLitModel(pl.LightningModule):
    def __init__(self, model):
        super(RegressionLitModel, self).__init__()
        self.model = model
        self.criterion = nn.MSELoss()

    def forward(self, x):
        return self.model(x)


    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self.model(x).squeeze() #verbosity
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x).squeeze()
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# Step 4: Training Script
model = RegressionModel()
lit_model = RegressionLitModel(model)

# Loggers
tb_logger = TensorBoardLogger("tb_logs", name="regression")
wandb_logger = WandbLogger(project="regression-example", name = "Experiment01")

# Detect if GPU is available and use it
gpus = 1 if torch.cuda.is_available() else 0

# Training
trainer = pl.Trainer(
    max_epochs=50,
    logger=[tb_logger, wandb_logger],
    callbacks=[ModelCheckpoint(monitor="val_loss")],
    log_every_n_steps=10,
    devices=gpus,
)

trainer.fit(lit_model, train_loader, val_loader)

# Close wandb run
wandb.finish()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: aiwand (txst) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251022_213908-wxzt0qbd</code>
# Syncing run <strong><a href='https://wandb.ai/txst/regression-example/runs/wxzt0qbd' target="_blank">Experiment01</a></strong> to <a href='https://wandb.ai/txst/regression-example' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# Initialize Wandb
# !wandb login
# Out:
# wandb: Currently logged in as: aiwand (txst). Use `wandb login --relogin` to force relogin

# %%
# Step 1: Data Preparation
class RegressionDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)
X, y = X.astype(np.float32), y.astype(np.float32)
dataset = RegressionDataset(X, y)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# Step 2: Model Definition
class RegressionModel(nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
        self.layer1 = nn.Linear(10, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = self.layer3(x)
        return x

# Step 3: LightningModule
class RegressionLitModel(pl.LightningModule):
    def __init__(self, model):
        super(RegressionLitModel, self).__init__()
        self.model = model
        self.criterion = nn.MSELoss()

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x).squeeze()
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss)

        # Log weight histograms to wandb
        for name, param in self.model.named_parameters():
            wandb.log({f"weights/{name}": wandb.Histogram(param.detach().cpu().numpy())})

        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x).squeeze()
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# Step 4: Training Script
model = RegressionModel()
lit_model = RegressionLitModel(model)

# Loggers
tb_logger = TensorBoardLogger("tb_logs", name="regression")
wandb_logger = WandbLogger(project="regression-example")

# Detect if GPU is available and use it
gpus = 1 if torch.cuda.is_available() else 0

# Training
trainer = pl.Trainer(
    max_epochs=50,
    logger=[tb_logger, wandb_logger],
    callbacks=[ModelCheckpoint(monitor="val_loss")],
    log_every_n_steps=10,
    devices=gpus
)

trainer.fit(lit_model, train_loader, val_loader)

# Close wandb run
wandb.finish()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>./wandb/run-20251022_214247-es9yymom</code>
# Syncing run <strong><a href='https://wandb.ai/txst/regression-example/runs/es9yymom' target="_blank">resilient-grass-2</a></strong> to <a href='https://wandb.ai/txst/regression-example' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/txst/regression-example' target="_blank">https://wandb.ai/txst/regression-example</a>
#  View run at <a href='https://wandb.ai/txst/regression-example/runs/es9yymom' target="_blank">https://wandb.ai/txst/regression-example/runs/es9yymom</a>
# ...

# %%
wandb.finish()
